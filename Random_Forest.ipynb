# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
# !ls CICIoMT2024
# Out:
# WiFI_and_MQTT

# %%
# Define the main directory path
main_folder_path = "CICIoMT2024/WiFI_and_MQTT/"

# %%
# Function to load CSV files into DataFrames with labels
def load_and_label_csv(file_path, label):
    # print(f"Reading file: {file_path}")
    df = pd.read_csv(file_path)
    df["Label"] = label
    return df


# Function to traverse directories and load CSV files with labels
def load_csv_files_with_labels(folder_path, label_mapping):
    all_data = pd.DataFrame()
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".csv"):
                file_path = os.path.join(root, file)
                label = label_mapping.get(file)
                if label is not None:
                    print(f"Loading file: {file_path} with label: {label}")
                    df = load_and_label_csv(file_path, label)
                    all_data = pd.concat([all_data, df], ignore_index=True)
    return all_data

# %%
# Define label mappings for 19 classes
label_mapping = {}

# Benign
for file in os.listdir(os.path.join(main_folder_path, "profiling/CSV")):
    label_mapping[file] = 0

# Spoofing - ARP
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "Spoofing" in file:
        label_mapping[file] = 1
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "Spoofing" in file:
        label_mapping[file] = 1

# DDoS - ICMP
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "DDoS-ICMP" in file:
        label_mapping[file] = 2
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "DDoS-ICMP" in file:
        label_mapping[file] = 2

# DDoS - SYN
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "DDoS-SYN" in file:
        label_mapping[file] = 3
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "DDoS-SYN" in file:
        label_mapping[file] = 3

# DDoS - TCP
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "DDoS-TCP" in file:
        label_mapping[file] = 4
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "DDoS-TCP" in file:
        label_mapping[file] = 4

# DDoS - UDP
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "DDoS-UDP" in file:
        label_mapping[file] = 5
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "DDoS-UDP" in file:
        label_mapping[file] = 5

# DoS - ICMP
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "DoS-ICMP" in file:
        label_mapping[file] = 6
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "DoS-ICMP" in file:
        label_mapping[file] = 6

# DoS - SYN
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "DoS-SYN" in file:
        label_mapping[file] = 7
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "DoS-SYN" in file:
        label_mapping[file] = 7

# DoS - TCP
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "DoS-TCP" in file:
        label_mapping[file] = 8
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "DoS-TCP" in file:
        label_mapping[file] = 8

# DoS - UDP
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "DoS-UDP" in file:
        label_mapping[file] = 9
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "DoS-UDP" in file:
        label_mapping[file] = 9

# MQTT DDoS - Connect Flood
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "MQTT-DDoS-Connect_Flood" in file:
        label_mapping[file] = 10
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "MQTT-DDoS-Connect_Flood" in file:
        label_mapping[file] = 10

# MQTT DDoS - Publish Flood
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "MQTT-DDoS-Publish_Flood" in file:
        label_mapping[file] = 11
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "MQTT-DDoS-Publish_Flood" in file:
        label_mapping[file] = 11

# MQTT DoS - Connect Flood
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "MQTT-DoS-Connect_Flood" in file:
        label_mapping[file] = 12
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "MQTT-DoS-Connect_Flood" in file:
        label_mapping[file] = 12

# MQTT DoS - Publish Flood
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "MQTT-DoS-Publish_Flood" in file:
        label_mapping[file] = 13
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "MQTT-DoS-Publish_Flood" in file:
        label_mapping[file] = 13

# MQTT Malformed Data
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "Malformed_Data" in file:
        label_mapping[file] = 14
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "Malformed_Data" in file:
        label_mapping[file] = 14

# Reconnaissance - OS Scan
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "OS_Scan" in file:
        label_mapping[file] = 15
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "OS_Scan" in file:
        label_mapping[file] = 15

# Reconnaissance - Ping Sweep
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "Ping_Sweep" in file:
        label_mapping[file] = 16
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "Ping_Sweep" in file:
        label_mapping[file] = 16

# Reconnaissance - Port Scan
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "Port_Scan" in file:
        label_mapping[file] = 17
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "Port_Scan" in file:
        label_mapping[file] = 17

# Reconnaissance - VulScan
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/test")):
    if "VulScan" in file:
        label_mapping[file] = 18
for file in os.listdir(os.path.join(main_folder_path, "attacks/csv/train")):
    if "VulScan" in file:
        label_mapping[file] = 18

# %%
# # Combine all label mappings
# label_mapping = {
#     **label_mapping_profiling,
#     **label_mapping_attacks_test,
#     **label_mapping_attacks_train,
# }


print("Loading profiling data (benign)...")
# Load the profiling CSV files (benign)
profiling_folder_path = os.path.join(main_folder_path, "profiling/CSV")
profiling_data = load_csv_files_with_labels(profiling_folder_path, label_mapping)

print("Loading attack data (malicious)...")
# Load the attack CSV files (malicious)
attack_folder_path_test = os.path.join(main_folder_path, "attacks/csv/test")
attack_folder_path_train = os.path.join(main_folder_path, "attacks/csv/train")
# Out:
# Loading profiling data (benign)...
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/SenseUBaby_Power.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Singcall_WAN_PHYSICAL.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Owltron_Camera_LAN_MIC.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Owltron_Camera_LAN_WATCH.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Blink_Camera_WAN_MIC.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/M1T_Camera_WAN_PHOTO.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Ecobee_Camera_LAN_MIC.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Owltron_Camera_WAN_WATCH.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/M1T_Camera_LAN_PHOTO.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Multifunctional_Pager_WAN_APP.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/M1T_Camera_Power.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Singcall_LAN_PHYSICAL.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Multifunctional_Pager_Power.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/M1T_Camera_LAN_PRECORDING.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/M1T_Camera_WAN_MIC.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Singcall_Power.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Ecobee_Camera_Power.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Blink_Camera_WAN_WATCH.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Multifunctional_Pager_LAN_PHYSICAL.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/SenseU_LAN_EMERGENCY.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/M1T_Camera_LAN_MIC.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/SenseU_WAN_EMERGENCY.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Blink_Camera_LAN_WATCH.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Owltron_Camera_Power.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/ActiveBroker.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Ecobee_Camera_WAN_MIC.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Owltron_Camera_WAN_RECORDING.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Ecobee_Camera_LAN_WATCH.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Multifunctional_Pager_WAN_PHYSICAL.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Owltron_Camera_LAN_PHOTO.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/M1T_Camera_WAN_WATCH.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/M1T_Camera_WAN_RECORDING.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Multifunctional_Pager_LAN_APP.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Active.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Ecobee_Camera_WAN_WATCH.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Owltron_Camera_WAN_PHOTO.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Blink_Camera_LAN_MIC.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Owltron_Camera_WAN_MIC.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Idle.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Owltron_Camera_LAN_RECORDING.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/M1T_Camera_LAN_WATCH.pcap.csv with label: 0
# Loading file: CICIoMT2024/WiFI_and_MQTT/profiling/CSV/Blink_Mini_Camera_Power.pcap.csv with label: 0
# Loading attack data (malicious)...

# %%
attack_data_test = load_csv_files_with_labels(attack_folder_path_test, label_mapping)
attack_data_train = load_csv_files_with_labels(attack_folder_path_train, label_mapping)


print("Combining data...")
# Combine the data
combined_data = pd.concat([profiling_data, attack_data_test, attack_data_train], ignore_index=True)
attack_data_test = load_csv_files_with_labels(
    attack_folder_path_test, label_mapping_attacks_test
)
attack_data_train = load_csv_files_with_labels(
    attack_folder_path_train, label_mapping_attacks_train
)


print("Combining data...")
# Combine the data
combined_data = pd.concat([profiling_data, attack_data_test, attack_data_train], ignore_index=True)
# Out:
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-ICMP1_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-UDP2_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/MQTT-DDoS-Connect_Flood_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/Recon-Port_Scan_test.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/MQTT-DoS-Publish_Flood_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-UDP1_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-ICMP2_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DoS-UDP_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DoS-SYN_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-SYN_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/Recon-OS_Scan_test.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/MQTT-DDoS-Publish_Flood_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/Recon-VulScan_test.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/Recon-Ping_Sweep_test.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/ARP_Spoofing_test.pcap.csv with label: 4
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/MQTT-DoS-Connect_Flood_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DoS-TCP_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-TCP_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DoS-ICMP_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/MQTT-Malformed_Data_test.pcap.csv with label: 5
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP8_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/MQTT-DoS-Publish_Flood_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP4_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-ICMP1_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-UDP2_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP3_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-SYN1_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP7_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-SYN1_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP6_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP2_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-UDP3_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/ARP_Spoofing_train.pcap.csv with label: 4
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP1_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-UDP4_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP5_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-ICMP2_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP3_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-SYN4_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP7_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/MQTT-Malformed_Data_train.pcap.csv with label: 5
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/Recon-VulScan_train.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP4_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/MQTT-DDoS-Publish_Flood_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP8_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-SYN2_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-SYN3_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-UDP1_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP1_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-ICMP4_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP5_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-SYN2_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-SYN3_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP6_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP2_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-ICMP3_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-SYN4_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/MQTT-DDoS-Connect_Flood_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-TCP1_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-TCP1_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/Recon-Ping_Sweep_train.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/Recon-Port_Scan_train.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/Recon-OS_Scan_train.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-TCP4_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/MQTT-DoS-Connect_Flood_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-TCP2_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-TCP3_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-TCP2_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-TCP3_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-TCP4_train.pcap.csv with label: 1
# Combining data...
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-ICMP1_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-UDP2_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/MQTT-DDoS-Connect_Flood_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/Recon-Port_Scan_test.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/MQTT-DoS-Publish_Flood_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-UDP1_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-ICMP2_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DoS-UDP_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DoS-SYN_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-SYN_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/Recon-OS_Scan_test.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/MQTT-DDoS-Publish_Flood_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/Recon-VulScan_test.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/Recon-Ping_Sweep_test.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/ARP_Spoofing_test.pcap.csv with label: 4
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/MQTT-DoS-Connect_Flood_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DoS-TCP_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DDoS-TCP_test.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/TCP_IP-DoS-ICMP_test.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/test/MQTT-Malformed_Data_test.pcap.csv with label: 5
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP8_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/MQTT-DoS-Publish_Flood_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP4_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-ICMP1_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-UDP2_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP3_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-SYN1_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP7_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-SYN1_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP6_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP2_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-UDP3_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/ARP_Spoofing_train.pcap.csv with label: 4
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP1_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-UDP4_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP5_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-ICMP2_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP3_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-SYN4_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP7_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/MQTT-Malformed_Data_train.pcap.csv with label: 5
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/Recon-VulScan_train.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP4_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/MQTT-DDoS-Publish_Flood_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP8_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-SYN2_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-SYN3_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-UDP1_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP1_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-ICMP4_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP5_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-SYN2_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-SYN3_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-UDP6_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-ICMP2_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-ICMP3_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-SYN4_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/MQTT-DDoS-Connect_Flood_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-TCP1_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-TCP1_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/Recon-Ping_Sweep_train.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/Recon-Port_Scan_train.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/Recon-OS_Scan_train.pcap.csv with label: 3
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-TCP4_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/MQTT-DoS-Connect_Flood_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-TCP2_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-TCP3_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DDoS-TCP2_train.pcap.csv with label: 2
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-TCP3_train.pcap.csv with label: 1
# Loading file: CICIoMT2024/WiFI_and_MQTT/attacks/csv/train/TCP_IP-DoS-TCP4_train.pcap.csv with label: 1
# Combining data...

# %%
print("Preprocessing data...")
# Preprocess the data
# Handling missing values by filling them with the mean of the column
combined_data.fillna(combined_data.mean(), inplace=True)

# Feature Selection: Drop columns that are not useful for classification
irrelevant_columns = ["Label"]  # Add any other non-numeric columns if needed
X = combined_data.drop(columns=irrelevant_columns)
y = combined_data["Label"]
# Out:
# Preprocessing data...

# %%
print("Standardizing data...")
# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# Standardizing data...

# %%
# %%

print("Splitting data into training and testing sets...")
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)


print(X_train, X_test)
print(y_train, y_test)
# Out:
# Splitting data into training and testing sets...
# [[-1.29868625e-01 -3.33901893e-01 -9.99581778e-02 ... -1.31304873e-01
#   -1.76946424e-01  8.99889466e-04]
#  [-3.78474230e-02  1.41192453e+00 -9.99581778e-02 ... -1.31309209e-01
#   -4.12682267e-01  8.99889466e-04]
#  [-1.30060753e-01 -3.33901893e-01 -9.99581778e-02 ... -1.31309209e-01
#   -4.12682267e-01  8.99889466e-04]
#  ...
#  [-8.52838942e-02  1.41192453e+00 -9.99581778e-02 ... -1.31309209e-01
#   -4.12682267e-01  8.99889466e-04]
#  [-1.30060753e-01 -3.33901893e-01 -9.99581778e-02 ... -1.31309209e-01
#   -4.12682267e-01  8.99889466e-04]
#  [-1.30188870e-01 -1.12745936e+00 -9.99581778e-02 ... -1.31309209e-01
#   -4.12682267e-01  8.99889466e-04]] [[-8.87929451e-02  1.41192453e+00 -9.99581778e-02 ... -1.28239491e-01
#   -1.76946424e-01  8.99889466e-04]
#  [-4.48993809e-02 -3.33901893e-01 -9.99581778e-02 ...  2.01993883e+00
#    2.10183339e+00  8.99889466e-04]
#  [-1.30060753e-01 -3.33901893e-01 -9.99581778e-02 ... -1.31309209e-01
#   -4.12682267e-01  8.99889466e-04]
#  ...
#  [-1.29931687e-01 -3.33901893e-01 -9.99581778e-02 ... -1.31296149e-01
#    5.87894187e-02  8.99889466e-04]
#  [-1.30188870e-01 -1.12745936e+00 -9.99581778e-02 ... -1.31309209e-01
#   -4.12682267e-01  8.99889466e-04]
#  [-1.30060753e-01 -3.33901893e-01 -9.99581778e-02 ... -1.31309209e-01
#   -4.12682267e-01  8.99889466e-04]]
# 1544898    2
# 6878944    2
# 7841152    2
# 1243968    1
# 5972720    2
#           ..
# 7204212    1
# 2234489    2
# 4304572    2
# 6550634    1
# 6423388    2
# Name: Label, Length: 7147704, dtype: int64 4229884    1
# 1594297    2
# 1807052    2
# 6242461    1
# 4077199    2
#           ..
# 597297     2
# 3389569    2
# 6740148    2
# 6153255    1
# 8292727    1
# Name: Label, Length: 1786926, dtype: int64

# %%
# %%

print("Training Random Forest Classifier...")
# Train a Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
# Out:
# Training Random Forest Classifier...
# RandomForestClassifier(random_state=42)

# %%
# %%

print("Predicting on the test set...")
# Predict on the test set
y_pred = clf.predict(X_test)
# Out:
# Predicting on the test set...

# %%
# %%
print("Printing classification report and accuracy...")
# Print classification report and accuracy
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Accuracy:", accuracy_score(y_test, y_pred))

print("Finished!")
# Out:
# Printing classification report and accuracy...
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     77918
#            1       1.00      1.00      1.00    458852
#            2       1.00      1.00      1.00   1218901
#            3       0.99      0.98      0.99     26387
#            4       0.92      0.83      0.87      3535
#            5       0.95      0.84      0.89      1333
#
#     accuracy                           1.00   1786926
#    macro avg       0.97      0.94      0.96   1786926
# weighted avg       1.00      1.00      1.00   1786926
#
# Accuracy: 0.9990296184620964
# Finished!
